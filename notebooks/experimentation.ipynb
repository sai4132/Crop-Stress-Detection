# %%
# !PYTHONPATH=..

# %%
from src.utils.paths import PROJECT_ROOT, RAW_DATA_DIR, PROCESSED_DATA_DIR

print (f"Project Root: {PROJECT_ROOT}")
print (f"Raw Data Directory: {RAW_DATA_DIR}")
print (f"Processed Data Directory: {PROCESSED_DATA_DIR}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from src.utils.paths import PROJECT_ROOT, RAW_DATA_DIR, PROCESSED_DATA_DIR
#       2
#       3 print (f"Project Root: {PROJECT_ROOT}")
#       4 print (f"Raw Data Directory: {RAW_DATA_DIR}")
#
# ModuleNotFoundError: No module named 'src'

# %%
import rasterio as rio

with rio.open("/Users/sai4132/Documents/Satwik/CV projects/Crop stress detection/data/raw/ROIs2017_winter 3/lc_8/ROIs2017_winter_lc_8_p30.tif") as dataset:
    print (dataset.count)
    print (dataset.width)
    print (dataset.height)
    print (dataset.crs)
    print (dataset.transform)
    print (dataset.dtypes)
    print(dataset.indexes)
    print(dataset.shape)
# Out:
# 4
# 256
# 256
# EPSG:32631
# | 10.00, 0.00, 252148.60|
# | 0.00,-10.00, 1961106.70|
# | 0.00, 0.00, 1.00|
# ('uint8', 'uint8', 'uint8', 'uint8')
# (1, 2, 3, 4)
# (256, 256)
